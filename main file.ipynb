# %%
# Import the required libraries and dependencies
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
import plotly.graph_objects as go
from scipy import stats
import plotly.express as px
import plotly.graph_objects as go

# %%
# Read csv file as DataFrame, with the first column as row index
df = pd.read_csv("Resources/survey.csv",
                 index_col="Timestamp",
                 parse_dates=True
                )

# Preview the dataset
df.head()
# Out:
#                      Age  Gender         Country state self_employed  \
# Timestamp
# 2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#                     family_history treatment work_interfere    no_employees  \
# Timestamp
# 2014-08-27 11:29:31             No       Yes          Often            6-25
# 2014-08-27 11:29:37             No        No         Rarely  More than 1000
# 2014-08-27 11:29:44             No        No         Rarely            6-25
# 2014-08-27 11:29:46            Yes       Yes          Often          26-100
# 2014-08-27 11:30:22             No        No          Never         100-500
#
#                     remote_work  ...               leave  \
# Timestamp                        ...
# 2014-08-27 11:29:31          No  ...       Somewhat easy
# 2014-08-27 11:29:37          No  ...          Don't know
# 2014-08-27 11:29:44          No  ...  Somewhat difficult
# 2014-08-27 11:29:46          No  ...  Somewhat difficult
# 2014-08-27 11:30:22         Yes  ...          Don't know
#
#                     mental_health_consequence phys_health_consequence  \
# Timestamp
# 2014-08-27 11:29:31                        No                      No
# 2014-08-27 11:29:37                     Maybe                      No
# 2014-08-27 11:29:44                        No                      No
# 2014-08-27 11:29:46                       Yes                     Yes
# 2014-08-27 11:30:22                        No                      No
#
#                         coworkers supervisor mental_health_interview  \
# Timestamp
# 2014-08-27 11:29:31  Some of them        Yes                      No
# 2014-08-27 11:29:37            No         No                      No
# 2014-08-27 11:29:44           Yes        Yes                     Yes
# 2014-08-27 11:29:46  Some of them         No                   Maybe
# 2014-08-27 11:30:22  Some of them        Yes                     Yes
#
#                     phys_health_interview mental_vs_physical obs_consequence  \
# Timestamp
# 2014-08-27 11:29:31                 Maybe                Yes              No
# 2014-08-27 11:29:37                    No         Don't know              No
# 2014-08-27 11:29:44                   Yes                 No              No
# 2014-08-27 11:29:46                 Maybe                 No             Yes
# 2014-08-27 11:30:22                   Yes         Don't know              No
#
#                     comments
# Timestamp
# 2014-08-27 11:29:31      NaN
# 2014-08-27 11:29:37      NaN
# 2014-08-27 11:29:44      NaN
# 2014-08-27 11:29:46      NaN
# 2014-08-27 11:30:22      NaN
#
# [5 rows x 26 columns]

# %%
#Creating a df that holds all of our quantifiable values(Y/N/Maybe answers)

my_df = df[['Gender', 'self_employed', 'work_interfere','benefits','care_options','wellness_program','seek_help','leave','mental_health_consequence','phys_health_consequence','family_history','treatment',
            'remote_work','tech_company','anonymity','coworkers','supervisor','mental_health_interview', 'phys_health_interview','mental_vs_physical','obs_consequence']]

my_df['work_interfere'] = my_df['work_interfere'].fillna('Unknown')

#function that uses replace_dict to iterate through dataframe and standardize to "Unknown"
def handle_uncertain_values(df, columns_to_check):
    replace_dict = {
        "Don't know": "Unknown",
        "Not sure": "Unknown",
        "NaN": "Unknown"
        
    }
    
    for col in columns_to_check:
        if my_df[col].dtype == 'object':  # For categorical columns
            my_df[col] = my_df[col].replace(replace_dict)
        else:  # For numeric columns
            my_df[col] = pd.to_numeric(my_df[col].replace(replace_dict, np.nan), errors='coerce')
    return df

# List of columns to check for uncertain values
columns_to_check = my_df.columns  # You can specify a subset of columns if needed

# Apply the function to handle uncertain values
df = handle_uncertain_values(df, columns_to_check)

# Print info about missing values
print(my_df.isnull().sum())
# Out:
# Gender                        0
# self_employed                18
# work_interfere                0
# benefits                      0
# care_options                  0
# wellness_program              0
# seek_help                     0
# leave                         0
# mental_health_consequence     0
# phys_health_consequence       0
# family_history                0
# treatment                     0
# remote_work                   0
# tech_company                  0
# anonymity                     0
# coworkers                     0
# supervisor                    0
# mental_health_interview       0
# phys_health_interview         0
# mental_vs_physical            0
# obs_consequence               0
# dtype: int64
# C:\Users\Connor\AppData\Local\Temp\ipykernel_3372\359437532.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Connor\AppData\Local\Temp\ipykernel_3372\359437532.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Changing values to fit the Y/N/Maybe numerical system i build later
condense_mapping = {
    'Somewhat easy': 'Easy',
    'Very easy': 'Easy',
    'Somewhat difficult': 'Difficult',
    'Very difficult': 'Difficult'
}
my_df['leave'] = my_df['leave'].replace(condense_mapping)

#Same as above
fun_mapping = {'Some of them':'Maybe'}

my_df['coworkers'] = my_df['coworkers'].replace(fun_mapping)

#changing work interfere into y/n as oppposed to 4 answers to help with correlation w/ small sample size
silly_mapping = {
    'Never': 'No',
    'Rarely': 'No',
    'Sometimes': 'Yes',
    'Often': 'Yes'
}
my_df['work_interfere'] = my_df['work_interfere'].replace(silly_mapping)

#Consolidating the gender column
my_df['Gender'].replace(['Male ', 'male', 'M', 'm', 'Male', 'Cis Male','Man', 'cis male', 'Mail', 'Male-ish', 'Male (CIS)',
                    'Cis Man', 'msle', 'Malr', 'Mal', 'maile', 'Make',], 'Male', inplace = True)

my_df['Gender'].replace(['Female ', 'female', 'F', 'f', 'Woman', 'Female','femail', 'Cis Female', 'cis-female/femme', 
                    'Femake', 'Female (cis)','woman',], 'Female', inplace = True)

my_df["Gender"].replace(['Female (trans)', 'queer/she/they', 'non-binary','fluid', 'queer', 'Androgyne', 'Trans-female', 'male leaning androgynous',
                      'Agender', 'A little about you', 'Nah', 'All','ostensibly male, unsure what that really means',
                      'Genderqueer', 'Enby', 'p', 'Neuter', 'something kinda male?','Guy (-ish) ^_^', 'Trans woman',], 'Non-Binary', inplace = True)

my_df['Gender'].value_counts()
# Out:
# C:\Users\Connor\AppData\Local\Temp\ipykernel_3372\210781789.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Connor\AppData\Local\Temp\ipykernel_3372\210781789.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Connor\AppData\Local\Temp\ipykernel_3372\210781789.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Connor\AppData\Local\Temp\ipykernel_3372\210781789.py:25: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#
# C:\Users\Connor\AppData\Local\Temp\ipykernel_3372\210781789.py:25: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Connor\AppData\Local\Temp\ipykernel_3372\210781789.py:28: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Connor\AppData\Local\Temp\ipykernel_3372\210781789.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Gender
# Male          991
# Female        247
# Non-Binary     21
# Name: count, dtype: int64

# %%
demographic_df = df[['treatment', 'self_employed', 'remote_work']]
clean_demographic_df = demographic_df.dropna()

# Calculate the total counts of 'Yes' and 'No' for each column
treatment_counts = clean_demographic_df['treatment'].value_counts()

# Filter the dataframe for 'treatment' == 'Yes'
treatment_yes_df = clean_demographic_df[clean_demographic_df['treatment'] == 'Yes']

self_employed_counts = treatment_yes_df['self_employed'].value_counts()
remote_work_counts = treatment_yes_df['remote_work'].value_counts()

#remote_work_counts

# Create a bar plot to visualize the counts and percentages
fig, ax = plt.subplots(3, 1, figsize=(8, 12))

# Function to annotate bars with counts and percentages
def annotate_bars(ax, counts):
    total = sum(counts)
    for i, count in enumerate(counts):
        percentage = count / total * 100
        ax.text(i, count + 5, f'{count}\n({percentage:.1f}%)', ha='center', va='bottom')

# Plot for 'treatment' column
ax[0].bar(treatment_counts.index, treatment_counts.values, color=['blue', 'orange'])
ax[0].set_ylabel('Count')
ax[0].set_title('Total respondents: Yes for in treatment vs. No, not in treatment')
ax[0].set_ylim(0, 700)  # Set the y-axis range to go up to 700
annotate_bars(ax[0], treatment_counts.values)

# Plot for 'self_employed' column
ax[1].bar(self_employed_counts.index, self_employed_counts.values, color=['blue', 'orange'])
ax[1].set_ylabel('Count')
ax[1].set_title('Self employed: Yes for in treatment vs. No, not in treatment')
ax[1].set_ylim(0, 700)  # Set the y-axis range to go up to 700
annotate_bars(ax[1], self_employed_counts.values)

# Plot for 'remote_work' column
ax[2].bar(remote_work_counts.index, remote_work_counts.values, color=['blue', 'orange'])
ax[2].set_ylabel('Count')
ax[2].set_title('Remote workers: Self employed: Yes for in treatment vs. No, not in treatment')
ax[2].set_ylim(0, 700)  # Set the y-axis range to go up to 700
annotate_bars(ax[2], remote_work_counts.values)

plt.tight_layout()
plt.show()

# %%
#since gender is nominal, and not representitive of some kind of value, I create a copy of our 3 gender choices, and they are assigned (T/F)

df_encoded = pd.get_dummies(my_df['Gender'], prefix='Gender')

my_df = pd.concat([my_df, df_encoded], axis=1)

# %%
#Dictionaries for maps I will be applying to all of my new columns. 

map2 = {'No': 0, 'Maybe': .5, 'Yes': 1}
map3 = {'No': 0, 'Yes': 1}
map4 = {'Difficult':0, 'Easy':1}


#Creating new columns by applying the map function to referenced column, converting all words to numbers 0-2
#there is surely a way to automate this
my_df['work_interfere_encoded'] = my_df['work_interfere'].map(map3)
my_df['benefits_encoded'] = my_df['benefits'].map(map3)
my_df['care_options_encoded'] = my_df['care_options'].map(map3)
my_df['wellness_program_encoded'] = my_df['wellness_program'].map(map3)
my_df['seek_help_encoded'] = my_df['seek_help'].map(map3)
my_df['leave_encoded'] = my_df['leave'].map(map4)
my_df['mental_health_consequence_encoded'] = my_df['mental_health_consequence'].map(map2)
my_df['phys_health_consequence_encoded'] = my_df['phys_health_consequence'].map(map2)
my_df['work_interfere_encoded'] = my_df['work_interfere'].map(map3)
my_df['family_history_encoded'] = my_df['family_history'].map(map3)
my_df['treatment_encoded'] = my_df['treatment'].map(map3)
my_df['remote_work_encoded'] = my_df['remote_work'].map(map3)
my_df['tech_company_encoded'] = my_df['tech_company'].map(map3)
my_df['anonymity_encoded'] = my_df['anonymity'].map(map3)
my_df['coworkers_encoded'] = my_df['coworkers'].map(map2)
my_df['supervisor_encoded'] = my_df['supervisor'].map(map3)
my_df['obs_consequence_encoded'] = my_df['obs_consequence'].map(map3)
my_df['mental_health_interview_encoded'] = my_df['mental_health_interview'].map(map2)
my_df['phys_health_interview_encoded']  = my_df['phys_health_interview'].map(map2)
my_df['mental_vs_physical_encoded'] = my_df['mental_vs_physical'].map(map3)
my_df['self_employed_encoded'] = my_df['self_employed'].map(map3)
#T/F can be converted using .astype(int)
my_df['Gender_Female_encoded']	= my_df['Gender_Female'].astype(int)
my_df['Gender_Male_encoded']	= my_df['Gender_Male'].astype(int)
my_df['Gender_Non-Binary_encoded']	= my_df['Gender_Non-Binary'].astype(int)



#selecting all the numeric(encoded) columns i just created and making a new numbers only df
numeric_columns = my_df.select_dtypes(include=[np.number]).columns
my_encoded_df = my_df[numeric_columns]

#matrix using df we just created, min_periods=1 allows it to pass over "Unknown" values, which helps a ton. Previously i was just dropping every 
#instance of "unknown" which reduced the df from 1200 to 150.
my_correlation_matrix = my_encoded_df.corr(method='pearson', min_periods=1)

         
display(my_correlation_matrix)

plt.figure(figsize=(20, 13))
sns.heatmap(my_correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()
# Out:
#                                    work_interfere_encoded  benefits_encoded  \
# work_interfere_encoded                           1.000000         -0.055287
# benefits_encoded                                -0.055287          1.000000
# care_options_encoded                             0.062836          0.352915
# wellness_program_encoded                        -0.044958          0.439193
# seek_help_encoded                               -0.087846          0.551535
# leave_encoded                                   -0.159728          0.225805
# mental_health_consequence_encoded                0.149519         -0.050123
# phys_health_consequence_encoded                  0.056958         -0.086812
# family_history_encoded                           0.228729          0.156482
# treatment_encoded                                0.401127          0.155897
# remote_work_encoded                              0.035524         -0.120223
# tech_company_encoded                             0.006273         -0.105018
# anonymity_encoded                               -0.027967          0.389723
# coworkers_encoded                                0.003036          0.021817
# supervisor_encoded                              -0.057653          0.064048
# obs_consequence_encoded                          0.125752         -0.049207
# mental_health_interview_encoded                 -0.052989         -0.037994
# phys_health_interview_encoded                    0.054702         -0.113981
# mental_vs_physical_encoded                      -0.137598          0.150090
# self_employed_encoded                            0.058128         -0.305171
# Gender_Female_encoded                            0.064864          0.171561
# Gender_Male_encoded                             -0.081160         -0.172084
# Gender_Non-Binary_encoded                        0.055240          0.017984
#
#                                    care_options_encoded  \
# work_interfere_encoded                         0.062836
# benefits_encoded                               0.352915
# care_options_encoded                           1.000000
# wellness_program_encoded                       0.354133
# seek_help_encoded                              0.390809
# leave_encoded                                  0.037291
# mental_health_consequence_encoded             -0.026021
# phys_health_consequence_encoded                0.005096
# family_history_encoded                         0.125619
# treatment_encoded                              0.278839
# remote_work_encoded                            0.012624
# tech_company_encoded                          -0.031537
# anonymity_encoded                              0.241460
# coworkers_encoded                              0.035060
# supervisor_encoded                             0.113989
# obs_consequence_encoded                        0.084167
# mental_health_interview_encoded                0.013051
# phys_health_interview_encoded                 -0.037578
# mental_vs_physical_encoded                     0.080235
# self_employed_encoded                          0.054791
# Gender_Female_encoded                          0.129092
# Gender_Male_encoded                           -0.153672
# Gender_Non-Binary_encoded                      0.090102
#
#                                    wellness_program_encoded  \
# work_interfere_encoded                            -0.044958
# benefits_encoded                                   0.439193
# care_options_encoded                               0.354133
# wellness_program_encoded                           1.000000
# seek_help_encoded                                  0.721095
# leave_encoded                                      0.183549
# mental_health_consequence_encoded                 -0.089877
# phys_health_consequence_encoded                   -0.014531
# family_history_encoded                             0.047738
# treatment_encoded                                  0.078018
# remote_work_encoded                               -0.061685
# tech_company_encoded                              -0.140112
# anonymity_encoded                                  0.273052
# coworkers_encoded                                  0.066198
# supervisor_encoded                                 0.147645
# obs_consequence_encoded                            0.067871
# mental_health_interview_encoded                   -0.008538
# phys_health_interview_encoded                     -0.050342
# mental_vs_physical_encoded                         0.296709
# self_employed_encoded                             -0.010513
# Gender_Female_encoded                              0.058854
# Gender_Male_encoded                               -0.072064
# Gender_Non-Binary_encoded                          0.045819
#
#                                    seek_help_encoded  leave_encoded  \
# work_interfere_encoded                     -0.087846      -0.159728
# benefits_encoded                            0.551535       0.225805
# care_options_encoded                        0.390809       0.037291
# wellness_program_encoded                    0.721095       0.183549
# seek_help_encoded                           1.000000       0.157697
# leave_encoded                               0.157697       1.000000
# mental_health_consequence_encoded          -0.130414      -0.444882
# phys_health_consequence_encoded            -0.057017      -0.279217
# family_history_encoded                      0.065877      -0.064382
# treatment_encoded                           0.082636      -0.159103
# remote_work_encoded                        -0.054195      -0.008502
# tech_company_encoded                       -0.156059       0.065386
# anonymity_encoded                           0.275376       0.380010
# coworkers_encoded                           0.050786       0.223455
# supervisor_encoded                          0.165679       0.410492
# obs_consequence_encoded                     0.053636      -0.293596
# mental_health_interview_encoded             0.017440       0.143168
# phys_health_interview_encoded              -0.050156       0.019301
# mental_vs_physical_encoded                  0.324555       0.530768
# self_employed_encoded                      -0.082244      -0.074827
# Gender_Female_encoded                       0.056920      -0.027592
# Gender_Male_encoded                        -0.054706       0.057940
# Gender_Non-Binary_encoded                  -0.000396      -0.088365
#
#                                    mental_health_consequence_encoded  \
# work_interfere_encoded                                      0.149519
# benefits_encoded                                           -0.050123
# care_options_encoded                                       -0.026021
# wellness_program_encoded                                   -0.089877
# seek_help_encoded                                          -0.130414
# leave_encoded                                              -0.444882
# mental_health_consequence_encoded                           1.000000
# phys_health_consequence_encoded                             0.515619
# family_history_encoded                                      0.097756
# treatment_encoded                                           0.132028
# remote_work_encoded                                        -0.008691
# tech_company_encoded                                       -0.114461
# anonymity_encoded                                          -0.398193
# coworkers_encoded                                          -0.443727
# supervisor_encoded                                         -0.651409
# obs_consequence_encoded                                     0.229827
# mental_health_interview_encoded                            -0.301990
# phys_health_interview_encoded                              -0.075323
# mental_vs_physical_encoded                                 -0.562655
# self_employed_encoded                                      -0.060767
# Gender_Female_encoded                                       0.082478
# Gender_Male_encoded                                        -0.108414
# Gender_Non-Binary_encoded                                   0.090770
#
#                                    phys_health_consequence_encoded  \
# work_interfere_encoded                                    0.056958
# benefits_encoded                                         -0.086812
# care_options_encoded                                      0.005096
# wellness_program_encoded                                 -0.014531
# seek_help_encoded                                        -0.057017
# leave_encoded                                            -0.279217
# mental_health_consequence_encoded                         0.515619
# phys_health_consequence_encoded                           1.000000
# family_history_encoded                                    0.060130
# treatment_encoded                                         0.051596
# remote_work_encoded                                       0.024952
# tech_company_encoded                                     -0.046020
# anonymity_encoded                                        -0.313312
# coworkers_encoded                                        -0.227011
# supervisor_encoded                                       -0.382648
# obs_consequence_encoded                                   0.182175
# mental_health_interview_encoded                          -0.089832
# phys_health_interview_encoded                            -0.177647
# mental_vs_physical_encoded                               -0.287550
# self_employed_encoded                                     0.040917
# Gender_Female_encoded                                     0.076983
# Gender_Male_encoded                                      -0.103895
# Gender_Non-Binary_encoded                                 0.093363
#
#                                    family_history_encoded  treatment_encoded  \
# work_interfere_encoded                           0.228729           0.401127
# benefits_encoded                                 0.156482           0.155897
# care_options_encoded                             0.125619           0.278839
# wellness_program_encoded                         0.047738           0.078018
# seek_help_encoded                                0.065877           0.082636
# leave_encoded                                   -0.064382          -0.159103
# mental_health_consequence_encoded                0.097756           0.132028
# phys_health_consequence_encoded                  0.060130           0.051596
# family_history_encoded                           1.000000           0.377918
# treatment_encoded                                0.377918           1.000000
# remote_work_encoded                              0.014456           0.026937
# tech_company_encoded                            -0.046079          -0.031525
# anonymity_encoded                               -0.045031           0.016970
# coworkers_encoded                               -0.000847           0.068433
# supervisor_encoded                               0.004159          -0.041834
# obs_consequence_encoded                          0.124861           0.156972
# mental_health_interview_encoded                 -0.059604          -0.048545
# phys_health_interview_encoded                   -0.040330           0.006225
# mental_vs_physical_encoded                      -0.080789          -0.084370
# self_employed_encoded                            0.009950           0.020598
# Gender_Female_encoded                            0.145425           0.180140
# Gender_Male_encoded                             -0.156169          -0.199503
# Gender_Non-Binary_encoded                        0.048219           0.079080
#
#                                    ...  coworkers_encoded  supervisor_encoded  \
# work_interfere_encoded             ...           0.003036           -0.057653
# benefits_encoded                   ...           0.021817            0.064048
# care_options_encoded               ...           0.035060            0.113989
# wellness_program_encoded           ...           0.066198            0.147645
# seek_help_encoded                  ...           0.050786            0.165679
# leave_encoded                      ...           0.223455            0.410492
# mental_health_consequence_encoded  ...          -0.443727           -0.651409
# phys_health_consequence_encoded    ...          -0.227011           -0.382648
# family_history_encoded             ...          -0.000847            0.004159
# treatment_encoded                  ...           0.068433           -0.041834
# remote_work_encoded                ...           0.082438            0.025673
# tech_company_encoded               ...           0.075383            0.057797
# anonymity_encoded                  ...           0.185166            0.340263
# coworkers_encoded                  ...           1.000000            0.620751
# supervisor_encoded                 ...           0.620751            1.000000
# obs_consequence_encoded            ...          -0.039472           -0.105742
# mental_health_interview_encoded    ...           0.326344            0.359495
# phys_health_interview_encoded      ...           0.144190            0.185378
# mental_vs_physical_encoded         ...           0.306876            0.480411
# self_employed_encoded              ...           0.080252            0.045151
# Gender_Female_encoded              ...          -0.055269           -0.092612
# Gender_Male_encoded                ...           0.048662            0.094671
# Gender_Non-Binary_encoded          ...           0.015842           -0.015796
#
#                                    obs_consequence_encoded  \
# work_interfere_encoded                            0.125752
# benefits_encoded                                 -0.049207
# care_options_encoded                              0.084167
# wellness_program_encoded                          0.067871
# seek_help_encoded                                 0.053636
# leave_encoded                                    -0.293596
# mental_health_consequence_encoded                 0.229827
# phys_health_consequence_encoded                   0.182175
# family_history_encoded                            0.124861
# treatment_encoded                                 0.156972
# remote_work_encoded                              -0.039065
# tech_company_encoded                             -0.062347
# anonymity_encoded                                -0.208560
# coworkers_encoded                                -0.039472
# supervisor_encoded                               -0.105742
# obs_consequence_encoded                           1.000000
# mental_health_interview_encoded                  -0.054550
# phys_health_interview_encoded                     0.039851
# mental_vs_physical_encoded                       -0.301650
# self_employed_encoded                             0.081926
# Gender_Female_encoded                             0.061725
# Gender_Male_encoded                              -0.086967
# Gender_Non-Binary_encoded                         0.086570
#
#                                    mental_health_interview_encoded  \
# work_interfere_encoded                                   -0.052989
# benefits_encoded                                         -0.037994
# care_options_encoded                                      0.013051
# wellness_program_encoded                                 -0.008538
# seek_help_encoded                                         0.017440
# leave_encoded                                             0.143168
# mental_health_consequence_encoded                        -0.301990
# phys_health_consequence_encoded                          -0.089832
# family_history_encoded                                   -0.059604
# treatment_encoded                                        -0.048545
# remote_work_encoded                                       0.086542
# tech_company_encoded                                      0.084365
# anonymity_encoded                                         0.103893
# coworkers_encoded                                         0.326344
# supervisor_encoded                                        0.359495
# obs_consequence_encoded                                  -0.054550
# mental_health_interview_encoded                           1.000000
# phys_health_interview_encoded                             0.448844
# mental_vs_physical_encoded                                0.228195
# self_employed_encoded                                     0.100162
# Gender_Female_encoded                                    -0.131693
# Gender_Male_encoded                                       0.092476
# Gender_Non-Binary_encoded                                 0.112777
#
#                                    phys_health_interview_encoded  \
# work_interfere_encoded                                  0.054702
# benefits_encoded                                       -0.113981
# care_options_encoded                                   -0.037578
# wellness_program_encoded                               -0.050342
# seek_help_encoded                                      -0.050156
# leave_encoded                                           0.019301
# mental_health_consequence_encoded                      -0.075323
# phys_health_consequence_encoded                        -0.177647
# family_history_encoded                                 -0.040330
# treatment_encoded                                       0.006225
# remote_work_encoded                                     0.034302
# tech_company_encoded                                    0.003009
# anonymity_encoded                                       0.041858
# coworkers_encoded                                       0.144190
# supervisor_encoded                                      0.185378
# obs_consequence_encoded                                 0.039851
# mental_health_interview_encoded                         0.448844
# phys_health_interview_encoded                           1.000000
# mental_vs_physical_encoded                             -0.011290
# self_employed_encoded                                   0.038255
# Gender_Female_encoded                                  -0.131429
# Gender_Male_encoded                                     0.122105
# Gender_Non-Binary_encoded                               0.017257
#
#                                    mental_vs_physical_encoded  \
# work_interfere_encoded                              -0.137598
# benefits_encoded                                     0.150090
# care_options_encoded                                 0.080235
# wellness_program_encoded                             0.296709
# seek_help_encoded                                    0.324555
# leave_encoded                                        0.530768
# mental_health_consequence_encoded                   -0.562655
# phys_health_consequence_encoded                     -0.287550
# family_history_encoded                              -0.080789
# treatment_encoded                                   -0.084370
# remote_work_encoded                                  0.112299
# tech_company_encoded                                 0.158776
# anonymity_encoded                                    0.353514
# coworkers_encoded                                    0.306876
# supervisor_encoded                                   0.480411
# obs_consequence_encoded                             -0.301650
# mental_health_interview_encoded                      0.228195
# phys_health_interview_encoded                       -0.011290
# mental_vs_physical_encoded                           1.000000
# self_employed_encoded                                0.155794
# Gender_Female_encoded                                0.026961
# Gender_Male_encoded                                 -0.018536
# Gender_Non-Binary_encoded                           -0.019003
#
#                                    self_employed_encoded  \
# work_interfere_encoded                          0.058128
# benefits_encoded                               -0.305171
# care_options_encoded                            0.054791
# wellness_program_encoded                       -0.010513
# seek_help_encoded                              -0.082244
# leave_encoded                                  -0.074827
# mental_health_consequence_encoded              -0.060767
# phys_health_consequence_encoded                 0.040917
# family_history_encoded                          0.009950
# treatment_encoded                               0.020598
# remote_work_encoded                             0.319680
# tech_company_encoded                            0.081577
# anonymity_encoded                              -0.060430
# coworkers_encoded                               0.080252
# supervisor_encoded                              0.045151
# obs_consequence_encoded                         0.081926
# mental_health_interview_encoded                 0.100162
# phys_health_interview_encoded                   0.038255
# mental_vs_physical_encoded                      0.155794
# self_employed_encoded                           1.000000
# Gender_Female_encoded                          -0.040845
# Gender_Male_encoded                             0.024119
# Gender_Non-Binary_encoded                       0.049048
#
#                                    Gender_Female_encoded  Gender_Male_encoded  \
# work_interfere_encoded                          0.064864            -0.081160
# benefits_encoded                                0.171561            -0.172084
# care_options_encoded                            0.129092            -0.153672
# wellness_program_encoded                        0.058854            -0.072064
# seek_help_encoded                               0.056920            -0.054706
# leave_encoded                                  -0.027592             0.057940
# mental_health_consequence_encoded               0.082478            -0.108414
# phys_health_consequence_encoded                 0.076983            -0.103895
# family_history_encoded                          0.145425            -0.156169
# treatment_encoded                               0.180140            -0.199503
# remote_work_encoded                            -0.007720             0.008641
# tech_company_encoded                           -0.074113             0.077931
# anonymity_encoded                              -0.033030             0.024670
# coworkers_encoded                              -0.055269             0.048662
# supervisor_encoded                             -0.092612             0.094671
# obs_consequence_encoded                         0.061725            -0.086967
# mental_health_interview_encoded                -0.131693             0.092476
# phys_health_interview_encoded                  -0.131429             0.122105
# mental_vs_physical_encoded                      0.026961            -0.018536
# self_employed_encoded                          -0.040845             0.024119
# Gender_Female_encoded                           1.000000            -0.950009
# Gender_Male_encoded                            -0.950009             1.000000
# Gender_Non-Binary_encoded                      -0.064344            -0.250449
#
#                                    Gender_Non-Binary_encoded
# work_interfere_encoded                              0.055240
# benefits_encoded                                    0.017984
# care_options_encoded                                0.090102
# wellness_program_encoded                            0.045819
# seek_help_encoded                                  -0.000396
# leave_encoded                                      -0.088365
# mental_health_consequence_encoded                   0.090770
# phys_health_consequence_encoded                     0.093363
# family_history_encoded                              0.048219
# treatment_encoded                                   0.079080
# remote_work_encoded                                -0.003681
# tech_company_encoded                               -0.019277
# anonymity_encoded                                   0.020512
# coworkers_encoded                                   0.015842
# supervisor_encoded                                 -0.015796
# obs_consequence_encoded                             0.086570
# mental_health_interview_encoded                     0.112777
# phys_health_interview_encoded                       0.017257
# mental_vs_physical_encoded                         -0.019003
# self_employed_encoded                               0.049048
# Gender_Female_encoded                              -0.064344
# Gender_Male_encoded                                -0.250449
# Gender_Non-Binary_encoded                           1.000000
#
# [23 rows x 23 columns]

# %%
display(my_df)

for i in ['Male', 'Female', 'Others']:
    t = df[df['Gender']==i].copy()
    fig = px.histogram(t, x='family_history',nbins=40,color='coworkers')
    fig.update_layout(
    title=i)
    fig.show()
# Out:
#                      Gender self_employed work_interfere benefits  \
# Timestamp
# 2014-08-27 11:29:31  Female           NaN            Yes      Yes
# 2014-08-27 11:29:37    Male           NaN             No  Unknown
# 2014-08-27 11:29:44    Male           NaN             No       No
# 2014-08-27 11:29:46    Male           NaN            Yes       No
# 2014-08-27 11:30:22    Male           NaN             No      Yes
# ...                     ...           ...            ...      ...
# 2015-09-12 11:17:21    Male            No        Unknown       No
# 2015-09-26 01:07:35    Male            No            Yes      Yes
# 2015-11-07 12:36:58    Male            No            Yes      Yes
# 2015-11-30 21:25:06  Female            No        Unknown       No
# 2016-02-01 23:04:31    Male            No            Yes      Yes
#
#                     care_options wellness_program seek_help      leave  \
# Timestamp
# 2014-08-27 11:29:31      Unknown               No       Yes       Easy
# 2014-08-27 11:29:37           No          Unknown   Unknown    Unknown
# 2014-08-27 11:29:44           No               No        No  Difficult
# 2014-08-27 11:29:46          Yes               No        No  Difficult
# 2014-08-27 11:30:22           No          Unknown   Unknown    Unknown
# ...                          ...              ...       ...        ...
# 2015-09-12 11:17:21           No               No        No       Easy
# 2015-09-26 01:07:35          Yes               No        No  Difficult
# 2015-11-07 12:36:58          Yes               No        No  Difficult
# 2015-11-30 21:25:06          Yes               No        No    Unknown
# 2016-02-01 23:04:31          Yes               No        No    Unknown
#
#                     mental_health_consequence phys_health_consequence  ...  \
# Timestamp                                                              ...
# 2014-08-27 11:29:31                        No                      No  ...
# 2014-08-27 11:29:37                     Maybe                      No  ...
# 2014-08-27 11:29:44                        No                      No  ...
# 2014-08-27 11:29:46                       Yes                     Yes  ...
# 2014-08-27 11:30:22                        No                      No  ...
# ...                                       ...                     ...  ...
# 2015-09-12 11:17:21                        No                      No  ...
# 2015-09-26 01:07:35                        No                      No  ...
# 2015-11-07 12:36:58                       Yes                     Yes  ...
# 2015-11-30 21:25:06                       Yes                      No  ...
# 2016-02-01 23:04:31                     Maybe                      No  ...
#
#                     coworkers_encoded supervisor_encoded  \
# Timestamp
# 2014-08-27 11:29:31               0.5                1.0
# 2014-08-27 11:29:37               0.0                0.0
# 2014-08-27 11:29:44               1.0                1.0
# 2014-08-27 11:29:46               0.5                0.0
# 2014-08-27 11:30:22               0.5                1.0
# ...                               ...                ...
# 2015-09-12 11:17:21               0.5                NaN
# 2015-09-26 01:07:35               0.5                1.0
# 2015-11-07 12:36:58               0.0                0.0
# 2015-11-30 21:25:06               0.0                0.0
# 2016-02-01 23:04:31               0.5                0.0
#
#                     obs_consequence_encoded mental_health_interview_encoded  \
# Timestamp
# 2014-08-27 11:29:31                       0                             0.0
# 2014-08-27 11:29:37                       0                             0.0
# 2014-08-27 11:29:44                       0                             1.0
# 2014-08-27 11:29:46                       1                             0.5
# 2014-08-27 11:30:22                       0                             1.0
# ...                                     ...                             ...
# 2015-09-12 11:17:21                       0                             0.0
# 2015-09-26 01:07:35                       0                             0.0
# 2015-11-07 12:36:58                       0                             0.0
# 2015-11-30 21:25:06                       0                             0.0
# 2016-02-01 23:04:31                       0                             0.0
#
#                     phys_health_interview_encoded mental_vs_physical_encoded  \
# Timestamp
# 2014-08-27 11:29:31                           0.5                        1.0
# 2014-08-27 11:29:37                           0.0                        NaN
# 2014-08-27 11:29:44                           1.0                        0.0
# 2014-08-27 11:29:46                           0.5                        0.0
# 2014-08-27 11:30:22                           1.0                        NaN
# ...                                           ...                        ...
# 2015-09-12 11:17:21                           0.0                        NaN
# 2015-09-26 01:07:35                           0.0                        1.0
# 2015-11-07 12:36:58                           0.0                        0.0
# 2015-11-30 21:25:06                           0.0                        0.0
# 2016-02-01 23:04:31                           0.0                        NaN
#
#                     self_employed_encoded Gender_Female_encoded  \
# Timestamp
# 2014-08-27 11:29:31                   NaN                     1
# 2014-08-27 11:29:37                   NaN                     0
# 2014-08-27 11:29:44                   NaN                     0
# 2014-08-27 11:29:46                   NaN                     0
# 2014-08-27 11:30:22                   NaN                     0
# ...                                   ...                   ...
# 2015-09-12 11:17:21                   0.0                     0
# 2015-09-26 01:07:35                   0.0                     0
# 2015-11-07 12:36:58                   0.0                     0
# 2015-11-30 21:25:06                   0.0                     1
# 2016-02-01 23:04:31                   0.0                     0
#
#                     Gender_Male_encoded Gender_Non-Binary_encoded
# Timestamp
# 2014-08-27 11:29:31                   0                         0
# 2014-08-27 11:29:37                   1                         0
# 2014-08-27 11:29:44                   1                         0
# 2014-08-27 11:29:46                   1                         0
# 2014-08-27 11:30:22                   1                         0
# ...                                 ...                       ...
# 2015-09-12 11:17:21                   1                         0
# 2015-09-26 01:07:35                   1                         0
# 2015-11-07 12:36:58                   1                         0
# 2015-11-30 21:25:06                   0                         0
# 2016-02-01 23:04:31                   1                         0
#
# [1259 rows x 47 columns]

# %%
#This code turns every float to a positive and then sums by row. Using to calculate total correlation (positive and negative). Printed are the rows in descending order.

positive_array = np.abs(my_correlation_matrix)
row_sums = np.sum(positive_array, axis=1)


sorted_indices = np.argsort(row_sums)[::-1]

# Sort the row sums in descending order
sorted_row_sums = row_sums[sorted_indices]

# Print the sorted results
print("Total Sum of Positive Entries by Row (Sorted in Descending Order):")
for idx in sorted_indices:
    print(f"Row {idx}: {sorted_row_sums[np.where(sorted_indices == idx)[0][0]]}")
# Out:
# Total Sum of Positive Entries by Row (Sorted in Descending Order):
# Row 6: 5.764944302027581
# Row 18: 5.7086224078921255
# Row 14: 5.463294452935836
# Row 5: 5.0350558526245255
# Row 1: 4.792951218102396
# Row 12: 4.785378214585954
# Row 4: 4.587071851530403
# Row 3: 4.272493671708222
# Row 7: 4.173283859288564
# Row 13: 4.121015493754741
# Row 21: 3.9588444537622633
# Row 16: 3.9024883359766016
# Row 2: 3.7109173509628146
# Row 9: 3.678292581011974
# Row 20: 3.6636598571281036
# Row 15: 3.5364894496452357
# Row 0: 3.007872885251101
# Row 8: 3.0005493143370443
# Row 17: 2.8433520623911366
# Row 19: 2.795143139935845
# Row 11: 2.603629853575318
# Row 22: 2.283894915526221
# Row 10: 2.2358503654316033
# C:\Users\Connor\AppData\Local\Temp\ipykernel_3372\2752375623.py:10: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# C:\Users\Connor\AppData\Local\Temp\ipykernel_3372\2752375623.py:15: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`

# %%
'''
HIGHEST CORRELATIONS

wellness_program
Has your employer ever discussed 
mental health as part of an employee wellness program?
BY
seek_help
Does your employer provide resources to 
learn more about mental health issues and how to seek help?


mental_health_consequence
Do you think that discussing a mental health issue with 
your employer would have negative consequences?
BY
supervisor         
Would you be willing to discuss a mental health issue with your direct supervisor?


supervisor
Would you be willing to discuss a mental health issue with your direct supervisor?
BY
coworkers
Would you be willing to discuss a mental health issue with your coworkers?


COLUMNS WITH HIGHEST TOTAL CORRELATION - USES ABOVE CODE - ALL CORRS POSITIVE AND SUMMED BY ROW

mental_health_consequence - 5.704177701107433
mental_vs_physical - 5.552828142779319
supervisor - 5.41814383868104
leave - 4.9602292596271775
anonymity - 4.724948546175345

'''
positive_array = np.abs(my_correlation_matrix)
row_sums = np.sum(positive_array, axis=1)

sorted_indices = np.argsort(row_sums)[::-1]

# Sort the row sums in descending order
sorted_row_sums = row_sums[sorted_indices]

# Plot the Pandas Series with custom index labels
sorted_row_sums.plot(kind='bar', color='skyblue', figsize=(10, 6))
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Plot of Pandas Series with Custom Index Labels')
plt.xticks(range(len(sorted_row_sums)), sorted_row_sums.index)  # Set custom index labels on x-axis
plt.show()
# Out:
# C:\Users\Connor\AppData\Local\Temp\ipykernel_3372\3462166580.py:43: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`

# %%
'''All of the entries in my_df are boiled down to Y/N/Maybe, but not all mean the same thing. For instance, if you look at 2 variables:

benefits:Does your employer provide mental health benefits? - Yes is a good thing, having benefits is positive for the employee

HOWEVER

mental_health_consequence: Do you think that discussing a mental health issue with your employer would have negative consequences? - Yes is a bad thing, there is a fear of punishment

THEREFORE I have attempted to create a system that helps us interpret this


YES = GOOD(does the company help support you?): ['benefits_encoded', 'care_options_encoded', wellness_program_encoded, seek_help_encoded, anonymity_encoded, leave_encoded, mental_vs_physical_encoded, 
                                coworkers_encoded, supervisor_encoded mental_health_interview, phys_health_interview]
                                
YES = BAD(Will the company punish you?): mental_health_consequence, phys_health_consequence, obv_consequence,
'''

# %%
#Creating dfs. My goal is to get the mean of each row of each dataframe, and see if there is a correlation between company support and company punishment
good_df = my_encoded_df[['benefits_encoded', 'care_options_encoded', 'wellness_program_encoded', 'seek_help_encoded', 'anonymity_encoded', 'leave_encoded', 'mental_vs_physical_encoded', 
                                'coworkers_encoded', 'supervisor_encoded', 'mental_health_interview_encoded', 'phys_health_interview_encoded']]

bad_df = my_encoded_df[['mental_health_consequence_encoded', 'phys_health_consequence_encoded', 'obs_consequence_encoded']]

#Calculating the mean of every row, and saving the values to a new column for respective df.
good_df['GoodMean'] = good_df.mean(axis=1)
bad_df['BadMean'] = bad_df.mean(axis=1)

#Creating new df containing only 2 columns we just created. 
combined_df = pd.DataFrame({
    'GoodMean': good_df['GoodMean'],
    'BadMean': bad_df['BadMean']
})


correlation = combined_df.corr().iloc[0, 1]
display("Correlation between GoodMean and BadMean:", correlation)
# display(combined_df)
#I can see that there is a -0.37% correlation between the values, which I would argue is meaningful.
# Out:
# C:\Users\Connor\AppData\Local\Temp\ipykernel_3372\3696027250.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Connor\AppData\Local\Temp\ipykernel_3372\3696027250.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 'Correlation between GoodMean and BadMean:'
# -0.3769107643382431

# %%
#Box plot that shows relationship between Good Means and Bad Means. Could use additional parameters to make it more informative
melted_df = combined_df.melt(value_vars=['GoodMean', 'BadMean'], var_name='Type', value_name='Mean')

plt.figure(figsize=(10, 6))
sns.boxplot(x='Type', y='Mean', data=melted_df)
plt.title('Box Plot of Good vs. Bad Means')
plt.xlabel('Type')
plt.ylabel('Mean')
plt.show()

# %%
#Graph that shows every row in df on x-axis, and the corresponding good and bad means for each. Very busy, hard to get info from, but I think there is good data hiding somewhere in there.

combined_df_reset = combined_df.reset_index(drop=True)

plt.figure(figsize=(10, 6))
plt.scatter(combined_df_reset['GoodMean'], combined_df_reset['BadMean'], alpha=0.5)

# Add trendline
z = np.polyfit(combined_df_reset['GoodMean'], combined_df_reset['BadMean'], 1)
p = np.poly1d(z)
plt.plot(combined_df_reset['GoodMean'], p(combined_df_reset['GoodMean']), "r--")

# Calculate correlation coefficient
corr, _ = stats.pearsonr(combined_df_reset['GoodMean'], combined_df_reset['BadMean'])

plt.title(f'Scatter plot of GoodMean vs BadMean\nCorrelation: {corr:.2f}')
plt.xlabel('GoodMean')
plt.ylabel('BadMean')
plt.grid(True)
plt.show()

#this explanation assumes we already know what GoodMean and BadMean are and how/why we calculated them
'''
This graph shows the relationship between our two values "GoodMean" and "BadMean". 
Starting off, I notice the top left of the graph. While it's a very small sample size, I see that of all values where
y=1, the majority of them are on the far left side of the graph. This very small trend is also represented with our trendline.

The trendline shows us that employees who are more likely to expect punishment for speaking on their health issues
are more likely to be at companies that do not go out of their way to support mental health(benefits, ease of leave, support from coworkers)

In short, companies that punish employees for speaking about their health concerns are less likely to offer benefits/support to their employees.
'''
# Out:
# '\nThis graph shows the relationship between our two values "GoodMean" and "BadMean". \nStarting off, I notice the top left of the graph. While it\'s a very small sample size, I see that of all values where\ny=1, the majority of them are on the far left side of the graph. This very small trend is also represented with our trendline.\n\nThe trendline shows us that employees who are more likely to expect punishment for speaking on their health issues\nare more likely to be at companies that do not go out of their way to support mental health(benefits, ease of leave, support from coworkers)\n\nIn short, companies that punish employees for speaking about their health concerns are less likely to offer benefits/support to their employees.\n'
